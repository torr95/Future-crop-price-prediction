# %% [markdown]
# <b>PART-I<b>

# %% [markdown]
# <b>Preprocessing of raw_wheat.csv to wheat.csv<b>

# %%
import pylab
import calendar
import numpy as np
import pandas as pd
import seaborn as sn
from scipy import stats
#import missingno as msno
from datetime import datetime
import matplotlib.pyplot as plt
import warnings
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore", category=DeprecationWarning)
# %matplotlib inline

# %%
daily_Data= pd.read_csv("/home/ayush/Documents/hackathon4/raw_wheat.csv")

# %%
daily_Data.head(2)
# Out:
#    Sl no. District Name Market Name Commodity Variety Grade  \
# 0       1      Bhatinda    Bathinda     Wheat   Other   FAQ
# 1       2      Bhatinda    Bathinda     Wheat   Other   FAQ
#
#    Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  Modal_Price Price_Date
# 0                     1120                     1125         1120  30 Apr 11
# 1                     1120                     1125         1120  29 Apr 11

# %%
daily_Data.shape
# Out:
# (1999, 10)

# %%
df=daily_Data.copy()

# %%
df.columns
# Out:
# Index(['Sl no.', 'District Name', 'Market Name', 'Commodity', 'Variety',
#        'Grade', 'Min Price (Rs./Quintal)', 'Max Price (Rs./Quintal)',
#        'Modal_Price', 'Price_Date'],
#       dtype='object')

# %%
df=df.rename(index=str, columns={"Sl no.": "Sl_no", "Min Price (Rs./Quintal)": "Min_Price","Price Date":"Price_Date","Modal Price (Rs./Quintal)":"Modal_Price"})

# %%
df.head()
# Out:
#    Sl_no District Name Market Name Commodity Variety Grade  Min_Price  \
# 0      1      Bhatinda    Bathinda     Wheat   Other   FAQ       1120
# 1      2      Bhatinda    Bathinda     Wheat   Other   FAQ       1120
# 2      3      Bhatinda    Bathinda     Wheat   Other   FAQ       1100
# 3      4      Bhatinda    Bathinda     Wheat   Other   FAQ       1100
# 4      5      Bhatinda    Bathinda     Wheat   Other   FAQ       1120
#
#    Max Price (Rs./Quintal)  Modal_Price Price_Date
# 0                     1125         1120  30 Apr 11
# 1                     1125         1120  29 Apr 11
# 2                     1100         1100  29 Apr 10
# 3                     1100         1100  28 Apr 10
# 4                     1120         1120  27 Apr 11

# %%
df.columns
# Out:
# Index(['Sl_no', 'District Name', 'Market Name', 'Commodity', 'Variety',
#        'Grade', 'Min_Price', 'Max Price (Rs./Quintal)', 'Modal_Price',
#        'Price_Date'],
#       dtype='object')

# %%
df.Price_Date = pd.to_datetime(df.Price_Date, errors='coerce')

# %%
df.head()
# Out:
#    Sl_no District Name Market Name Commodity Variety Grade  Min_Price  \
# 0      1      Bhatinda    Bathinda     Wheat   Other   FAQ       1120
# 1      2      Bhatinda    Bathinda     Wheat   Other   FAQ       1120
# 2      3      Bhatinda    Bathinda     Wheat   Other   FAQ       1100
# 3      4      Bhatinda    Bathinda     Wheat   Other   FAQ       1100
# 4      5      Bhatinda    Bathinda     Wheat   Other   FAQ       1120
#
#    Max Price (Rs./Quintal)  Modal_Price Price_Date
# 0                     1125         1120 2011-04-30
# 1                     1125         1120 2011-04-29
# 2                     1100         1100 2010-04-29
# 3                     1100         1100 2010-04-28
# 4                     1120         1120 2011-04-27

# %%
df=df.sort_values(by='Price_Date')

# %%
df.drop_duplicates('Price_Date', inplace = True)

# %%
df.head(20)
# Out:
#       Sl_no District Name              Market Name Commodity Variety Grade  \
# 34       35      Bhatinda                 Bathinda     Wheat   Other   FAQ
# 33       34      Bhatinda                 Bathinda     Wheat   Other   FAQ
# 31       32      Bhatinda                 Bathinda     Wheat   Other   FAQ
# 30       31      Bhatinda                 Bathinda     Wheat   Other   FAQ
# 1644   1645      Bhatinda                   Sangat     Wheat   Other   FAQ
# 962     963      Bhatinda             Rampura Phul     Wheat   Other   FAQ
# 960     961      Bhatinda             Rampura Phul     Wheat   Other   FAQ
# 1618   1619      Bhatinda                   Sangat     Wheat   Other   FAQ
# 1064   1065      Bhatinda  Rampuraphul(Bhai Rupan)     Wheat   Other   FAQ
# 1061   1062      Bhatinda  Rampuraphul(Bhai Rupan)     Wheat   Other   FAQ
# 23       24      Bhatinda                 Bathinda     Wheat   Other   FAQ
# 1783   1784      Bhatinda            Talwandi Sabo     Wheat   Other   FAQ
# 1149   1150      Bhatinda      Rampuraphul(Chowke)     Wheat   Other   FAQ
# 304     305      Bhatinda                   Bhucho     Wheat   Kanak   FAQ
# 1556   1557      Bhatinda                   Sangat     Wheat   Other   FAQ
# 1546   1547      Bhatinda                   Sangat     Wheat   Other   FAQ
# 276     277      Bhatinda                   Bhucho     Wheat   Kanak   FAQ
# 13       14      Bhatinda                 Bathinda     Wheat   Other   FAQ
# 258     259      Bhatinda                   Bhucho     Wheat   Kanak   FAQ
# 249     250      Bhatinda                   Bhucho     Wheat   Kanak   FAQ
#
#       Min_Price  Max Price (Rs./Quintal)  Modal_Price Price_Date
# 34         1100                     1100         1100 2010-04-06
# 33         1100                     1100         1100 2010-04-07
# 31         1100                     1100         1100 2010-04-08
# 30         1100                     1100         1100 2010-04-09
# 1644       1100                     1100         1100 2010-04-10
# 962        1100                     1100         1100 2010-04-11
# 960        1100                     1100         1100 2010-04-12
# 1618       1100                     1100         1100 2010-04-13
# 1064       1100                     1100         1100 2010-04-14
# 1061       1100                     1100         1100 2010-04-15
# 23         1100                     1100         1100 2010-04-16
# 1783       1100                     1100         1100 2010-04-17
# 1149       1100                     1100         1100 2010-04-18
# 304        1100                     1100         1100 2010-04-19
# 1556       1100                     1105         1100 2010-04-20
# 1546       1100                     1105         1100 2010-04-21
# 276        1100                     1100         1100 2010-04-22
# 13         1100                     1100         1100 2010-04-23
# 258        1100                     1100         1100 2010-04-24
# 249        1100                     1100         1100 2010-04-25

# %% [markdown]
# <b>Saving to wheat.csv for future price prediction<b>

# %%
df.to_csv("/home/ayush/Documents/hackathon4/wheat.csv", sep=',')
